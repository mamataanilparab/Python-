# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading a csv file from local disk

# %%
data=pd.read_csv("C:\\Users\\Larry Williams\\Desktop\\Mamata\\Edvancer\\data\\data\\heart.csv")

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ### Plots

# %%
plt.hist(data["age"])
# Out:
# (array([ 1., 11., 33., 38., 37., 60., 63., 43., 14.,  3.]),
#  array([29. , 33.8, 38.6, 43.4, 48.2, 53. , 57.8, 62.6, 67.4, 72.2, 77. ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(data["age"])

# %%
plt.boxplot(data["age"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e34529ab08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e34529fac8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e345293fc8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e3452a3a48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e3452a3b48>],
#  'means': []}

# %%
sns.boxplot(data["age"])

# %%
a=pd.Series(data['age']).plot(kind="density")

# %%
plt.bar(data["cp"],height=0.5)
# Out:
# <BarContainer object of 303 artists>

# %%
sns.countplot(data["cp"])

# %%
plt.bar(data["thal"],height=0.2)
# Out:
# <BarContainer object of 303 artists>

# %%
sns.countplot(data["thal"])

# %%
sns.regplot(data["age"],data["oldpeak"],fit_reg=False)

# %%
sns.lineplot(data["age"],data["oldpeak"])

# %%
a=data.boxplot(column="age",by="thal")

# %%
b=data.boxplot(column="oldpeak",by="cp")

# %%
sns.countplot(x="sex",hue="target",data=data)

# %%
sns.countplot(x="sex",hue="target",data=data,dodge=False)

# %%
fig,axes=plt.subplots(ncols=5,figsize=(25,5))
sns.countplot(data["sex"],ax=axes[0],palette="Blues")
sns.countplot(data["cp"],ax=axes[1],palette="Set2")
sns.countplot(data["fbs"],ax=axes[2],palette="viridis")
sns.countplot(data["restecg"],ax=axes[3],palette="summer")
sns.countplot(data["exang"],ax=axes[4],palette="winter")

# %%
fig,axes=plt.subplots(ncols=4,figsize=(25,5))
sns.countplot(data['slope'],ax=axes[0],palette="spring")
sns.countplot(data["ca"],ax=axes[1],palette="muted")
sns.countplot(data["thal"],ax=axes[2],palette="magma")
sns.countplot(data["target"],ax=axes[3],palette="copper")
