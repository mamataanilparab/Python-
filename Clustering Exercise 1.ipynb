# %% [markdown]
# # Cluster Visualiation

# %% [markdown]
# ### Importing required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading the data

# %%
data=pd.read_csv('https://raw.githubusercontent.com/benjaminwilson/python-clustering-exercises/master/datasets/ch1ex1.csv')

# %%
data2=data.values
data2
# Out:
# array([[ 0.06544649, -0.76866376],
#        [-1.52901547, -0.42953079],
#        [ 1.70993371,  0.69885253],
#        [ 1.16779145,  1.01262638],
#        [-1.80110088, -0.31861296],
#        [-1.63567888, -0.02859535],
#        [ 1.21990375,  0.74643463],
#        [-0.26175155, -0.62492939],
#        [-1.61925804, -0.47983949],
#        [-1.84329582, -0.16694431],
#        [ 1.35999602,  0.94995827],
#        [ 0.42291856, -0.7349534 ],
#        [-1.68576139,  0.10686728],
#        [ 0.90629995,  1.09105162],
#        [-1.56478322, -0.84675394],
#        [-0.0257849 , -1.18672539],
#        [ 0.83027324,  1.14504612],
#        [ 1.22450432,  1.35066759],
#        [-0.15394596, -0.71704301],
#        [ 0.86358809,  1.06824613],
#        [-1.43386366, -0.2381297 ],
#        [ 0.03844769, -0.74635022],
#        [-1.58567922,  0.08499354],
#        [ 0.6359888 , -0.58477698],
#        [ 0.24417242, -0.53172465],
#        [-2.19680359,  0.49473677],
#        [ 1.0323503 , -0.55688   ],
# ...

# %% [markdown]
# ### Create an array called first that contains the values of data2[:,0] - that is, column 0 of data2:

# %%
first= data2[:,0]

# %% [markdown]
# ### Create an array called second that contains the values of data2[:,1] - that is, column 1 of data2:

# %%
second= data2[:, 1]

# %% [markdown]
# ### Scatter plot

# %%
plt.scatter(first, second)
